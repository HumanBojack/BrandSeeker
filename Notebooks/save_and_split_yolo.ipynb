# %%
import xml.etree.ElementTree as ET
import glob
import os
import json

# %%
def xml_to_yolo_bbox(bbox, w, h):
    # xmin, ymin, xmax, ymax
    x_center = min(((bbox[2] + bbox[0]) / 2) / w,1)
    y_center = min(((bbox[3] + bbox[1]) / 2) / h,1)
    width = min((bbox[2] - bbox[0]) / w,1)
    height = min((bbox[3] - bbox[1]) / h,1)
    return [x_center, y_center, width, height]
def yolo_to_xml_bbox(bbox, w, h):
    # x_center, y_center width heigth
    w_half_len = (bbox[2] * w) / 2
    h_half_len = (bbox[3] * h) / 2
    xmin = int((bbox[0] * w) - w_half_len)
    ymin = int((bbox[1] * h) - h_half_len)
    xmax = int((bbox[0] * w) + w_half_len)
    ymax = int((bbox[1] * h) + h_half_len)
    return [xmin, ymin, xmax, ymax]

# %%
classes = []
input_dir = "annotations/"
output_dir = "labels/"
image_dir = "images/"
os.mkdir(output_dir)

# %%
files = glob.glob(os.path.join(input_dir, '*.xml'))
for fil in files:
    basename = os.path.basename(fil)
    filename = os.path.splitext(basename)[0]
    # check if the label contains the corresponding image file
    if not os.path.exists(os.path.join(image_dir, f"{filename}.png")):
        print(f"{filename} image does not exist!")
        continue

    result = []

    # parse the content of the xml file
    tree = ET.parse(fil)
    root = tree.getroot()
    width = int(root.find("size").find("width").text)
    height = int(root.find("size").find("height").text)

    for obj in root.findall('object'):
        label = obj.find("name").text
        # check for new classes and append to list
        if label not in classes:
            classes.append(label)
        index = classes.index(label)
        pil_bbox = [int(x.text) for x in obj.find("bndbox")]
        yolo_bbox = xml_to_yolo_bbox(pil_bbox, width, height)
        # convert data to string
        bbox_string = " ".join([str(x) for x in yolo_bbox])
        result.append(f"{index} {bbox_string}")

    if result:
        # generate a YOLO format text file for each xml file
        with open(os.path.join(output_dir, f"{filename}.txt"), "w", encoding="utf-8") as f:
            f.write("\n".join(result))

# generate the classes file as reference

# %%
with open('classes.txt', 'w', encoding='utf8') as f:
    f.write(json.dumps(classes))

# %% [markdown]
# # split data

# %%
J = 'kiwi_co__1_1'
J.rfind('_')
J[:10]
# Out:
# 'kiwi_co__1'

# %%
img_dir = 'images/'
txt_dir = 'labels/'
#dir = 'drive/MyDrive/no_resize_no_augmentation/'
import os
import random
import shutil

nb_image = len(os.listdir(img_dir))
list_images = []
for i in os.listdir(img_dir):
  if i[i.find('__')+2:].find('_') == -1 or (i.find('logo') != -1 and i[i.find('__')+2:].count('_') == 1):
    list_images.append(i)
random.shuffle(list_images)

test_images = list_images[:int(len(list_images)/10)]
train_images = list_images[len(test_images):]
test_txt = [x[:-3]+ 'txt' for x in test_images]
train_txt = [x[:-3]+ 'txt' for x in train_images]
train_txt
# Out:
# ['dollar_shave_club__logo_0.txt',
#  'worlds_of_warships__logo_32.txt',
#  'redbull__6.txt',
#  'gfuel__logo_13.txt',
#  'dollar_shave_club__logo_40.txt',
#  'displate__logo_41.txt',
#  'republic_of_gamers__14.txt',
#  'microsoft__15.txt',
#  'skillshare__logo_11.txt',
#  'squarespace__logo_29.txt',
#  'coca_cola__17.txt',
#  'republic_of_gamers__logo_2.txt',
#  'surfshark__logo_10.txt',
#  'nordvpn__4.txt',
#  'coca_cola__38.txt',
#  'republic_of_gamers__logo_44.txt',
#  'amazon__24.txt',
#  'brilliant_org__logo_35.txt',
#  'squarespace__logo_38.txt',
#  'raid_shadow_legends__logo_15.txt',
#  'uber_eats__34.txt',
#  'ridge_wallet__logo_19.txt',
#  'logitech__logo_23.txt',
#  'uber_eats__logo_38.txt',
#  'redbull__logo_9.txt',
#  'state_of_survival__12.txt',
#  'ridge_wallet__38.txt',
#  'manscaped__logo_12.txt',
#  'raid_shadow_legends__34.txt',
#  'squarespace__logo_7.txt',
#  'worlds_of_warships__10.txt',
#  'worlds_of_warships__60.txt',
#  'squarespace__logo_24.txt',
#  'winamax__36.txt',
#  'amazon__logo_14.txt',
#  'skillshare__logo_36.txt',
#  'skillshare__10.txt',
#  'squarespace__10.txt',
#  'winamax__1.txt',
#  'republic_of_gamers__logo_49.txt',
#  'logitech__37.txt',
#  'worlds_of_warships__logo_11.txt',
#  'levlup__logo_37.txt',
#  'raid_shadow_legends__16.txt',
#  'skillshare__1.txt',
#  'dollar_shave_club__21.txt',
#  'dollar_shave_club__47.txt',
#  'world_of_tanks__logo_23.txt',
#  'winamax__logo_38.txt',
#  'tunnelbear_vpn__24.txt',
#  'winamax__logo_46.txt',
#  'republic_of_gamers__37.txt',
#  'squarespace__logo_10.txt',
#  'redbull__logo_0.txt',
#  'redbull__36.txt',
#  'hello_fresh__logo_40.txt',
#  'expressvpn__logo_33.txt',
#  'tunnelbear_vpn__13.txt',
#  'logitech__logo_34.txt',
#  'crunchyroll__logo_43.txt',
#  'surfshark__21.txt',
#  'surfshark__logo_18.txt',
#  'expressvpn__19.txt',
#  'surfshark__logo_13.txt',
#  'expressvpn__30.txt',
#  'gfuel__logo_21.txt',
#  'gfuel__1.txt',
#  'worlds_of_warships__logo_24.txt',
#  'levlup__logo_23.txt',
#  'worlds_of_warships__logo_46.txt',
#  'nordvpn__25.txt',
#  'hello_fresh__22.txt',
#  'war_thunder__23.txt',
#  'crunchyroll__logo_45.txt',
#  'manscaped__38.txt',
#  'winamax__logo_3.txt',
#  'kiwico__logo_5.txt',
#  'levlup__41.txt',
#  'hello_fresh__logo_11.txt',
#  'displate__logo_22.txt',
#  'nordvpn__logo_2.txt',
#  'gorillas__logo_18.txt',
#  'gfuel__40.txt',
#  'raid_shadow_legends__15.txt',
#  'lootcrate__logo_36.txt',
#  'redbull__8.txt',
#  'dollar_shave_club__logo_31.txt',
#  'republic_of_gamers__33.txt',
#  'dbrand__logo_9.txt',
#  'levlup__12.txt',
#  'squarespace__logo_6.txt',
#  'logitech__logo_3.txt',
#  'genshin_impact__10.txt',
#  'logitech__43.txt',
#  'coca_cola__53.txt',
#  'uber_eats__38.txt',
#  'hello_fresh__3.txt',
#  'gfuel__27.txt',
#  'manscaped__24.txt',
#  'displate__40.txt',
#  'uber_eats__13.txt',
#  'gfuel__logo_1.txt',
#  'surfshark__6.txt',
#  'winamax__9.txt',
#  'tunnelbear_vpn__8.txt',
#  'corsair__23.txt',
#  'displate__logo_26.txt',
#  'republic_of_gamers__0.txt',
#  'microsoft__logo_38.txt',
#  'raid_shadow_legends__logo_5.txt',
#  'winamax__logo_9.txt',
#  'logitech__17.txt',
#  'displate__logo_1.txt',
#  'gfuel__logo_37.txt',
#  'nordvpn__36.txt',
#  'winamax__logo_37.txt',
#  'redbull__22.txt',
#  'displate__logo_12.txt',
#  'levlup__5.txt',
#  'uber_eats__logo_14.txt',
#  'skillshare__17.txt',
#  'winamax__6.txt',
#  'levlup__logo_45.txt',
#  'ridge_wallet__9.txt',
#  'manscaped__logo_30.txt',
#  'skillshare__logo_27.txt',
#  'crunchyroll__15.txt',
#  'coca_cola__logo_12.txt',
#  'audible__logo_21.txt',
#  'audible__27.txt',
#  'redbull__42.txt',
#  'brilliant_org__logo_32.txt',
#  'hello_fresh__logo_9.txt',
#  'ridge_wallet__3.txt',
#  'republic_of_gamers__logo_47.txt',
#  'winamax__logo_10.txt',
#  'world_of_tanks__logo_36.txt',
#  'ridge_wallet__26.txt',
#  'nordvpn__logo_17.txt',
#  'brilliant_org__logo_16.txt',
#  'lootcrate__2.txt',
#  'ridge_wallet__36.txt',
#  'republic_of_gamers__4.txt',
#  'kiwico__logo_28.txt',
#  'logitech__logo_12.txt',
#  'microsoft__5.txt',
#  'hello_fresh__logo_15.txt',
#  'redbull__49.txt',
#  'fruitz__logo_14.txt',
#  'nordvpn__logo_24.txt',
#  'surfshark__44.txt',
#  'squarespace__logo_14.txt',
#  'kiwico__logo_24.txt',
#  'genshin_impact__27.txt',
#  'gfuel__logo_28.txt',
#  'levlup__4.txt',
#  'nordvpn__logo_34.txt',
#  'worlds_of_warships__logo_17.txt',
#  'dbrand__logo_35.txt',
#  'gfuel__logo_4.txt',
#  'war_thunder__39.txt',
#  'gfuel__31.txt',
#  'lootcrate__4.txt',
#  'worlds_of_warships__21.txt',
#  'amazon__14.txt',
#  'genshin_impact__46.txt',
#  'fruitz__logo_7.txt',
#  'winamax__12.txt',
#  'war_thunder__logo_20.txt',
#  'gorillas__38.txt',
#  'hello_fresh__logo_35.txt',
#  'world_of_tanks__logo_13.txt',
#  'kiwico__logo_6.txt',
#  'honey__logo_40.txt',
#  'hello_fresh__logo_26.txt',
#  'expressvpn__logo_26.txt',
#  'microsoft__31.txt',
#  'republic_of_gamers__logo_34.txt',
#  'expressvpn__28.txt',
#  'redbull__logo_30.txt',
#  'logitech__22.txt',
#  'ridge_wallet__10.txt',
#  'microsoft__45.txt',
#  'redbull__logo_4.txt',
#  'dollar_shave_club__logo_26.txt',
#  'redbull__10.txt',
#  'microsoft__36.txt',
#  'logitech__logo_42.txt',
#  'ridge_wallet__21.txt',
#  'audible__logo_13.txt',
#  'expressvpn__logo_3.txt',
#  'lootcrate__21.txt',
#  'logitech__logo_43.txt',
#  'squarespace__35.txt',
#  'republic_of_gamers__16.txt',
#  'coca_cola__logo_4.txt',
#  'world_of_tanks__38.txt',
#  'winamax__logo_31.txt',
#  'tunnelbear_vpn__logo_7.txt',
#  'gfuel__logo_30.txt',
#  'tunnelbear_vpn__36.txt',
#  'crunchyroll__10.txt',
#  'world_of_tanks__30.txt',
#  'manscaped__logo_40.txt',
#  'uber_eats__logo_18.txt',
#  'microsoft__logo_23.txt',
#  'amazon__logo_17.txt',
#  'logitech__logo_0.txt',
#  'rhinoshield__logo_12.txt',
#  'worlds_of_warships__logo_1.txt',
#  'winamax__logo_43.txt',
#  'redbull__logo_5.txt',
#  'republic_of_gamers__35.txt',
#  'dbrand__43.txt',
#  'surfshark__36.txt',
#  'coca_cola__logo_43.txt',
#  'microsoft__35.txt',
#  'coca_cola__logo_31.txt',
#  'honey__34.txt',
#  'uber_eats__18.txt',
#  'redbull__34.txt',
#  'nordvpn__logo_1.txt',
#  'displate__logo_30.txt',
#  'crunchyroll__6.txt',
#  'nordvpn__22.txt',
#  'coca_cola__logo_39.txt',
#  'uber_eats__logo_5.txt',
#  'uber_eats__45.txt',
#  'winamax__31.txt',
#  'hello_fresh__44.txt',
#  'nordvpn__logo_29.txt',
#  'lootcrate__logo_9.txt',
#  'levlup__39.txt',
#  'brilliant_org__34.txt',
#  'amazon__56.txt',
#  'raid_shadow_legends__logo_38.txt',
#  'squarespace__logo_36.txt',
#  'uber_eats__37.txt',
#  'logitech__logo_32.txt',
#  'squarespace__logo_1.txt',
#  'corsair__logo_1.txt',
#  'corsair__logo_23.txt',
#  'logitech__logo_37.txt',
#  'gfuel__36.txt',
#  'uber_eats__logo_41.txt',
#  'logitech__logo_27.txt',
#  'ridge_wallet__5.txt',
#  'corsair__logo_38.txt',
#  'raid_shadow_legends__22.txt',
#  'lootcrate__38.txt',
#  'redbull__logo_44.txt',
#  'logitech__34.txt',
#  'surfshark__logo_4.txt',
#  'republic_of_gamers__logo_36.txt',
#  'crunchyroll__logo_0.txt',
#  'squarespace__49.txt',
#  'raid_shadow_legends__2.txt',
#  'levlup__20.txt',
#  'corsair__36.txt',
#  'republic_of_gamers__logo_29.txt',
#  'brilliant_org__logo_31.txt',
#  'tunnelbear_vpn__43.txt',
#  'expressvpn__logo_16.txt',
#  'levlup__32.txt',
#  'kiwico__logo_32.txt',
#  'worlds_of_warships__logo_7.txt',
#  'logitech__logo_19.txt',
#  'amazon__logo_26.txt',
#  'republic_of_gamers__10.txt',
#  'microsoft__logo_35.txt',
#  'republic_of_gamers__22.txt',
#  'gorillas__36.txt',
#  'amazon__logo_6.txt',
#  'displate__logo_36.txt',
#  'microsoft__16.txt',
#  'raid_shadow_legends__25.txt',
#  'expressvpn__logo_19.txt',
#  'microsoft__27.txt',
#  'displate__logo_9.txt',
#  'dbrand__logo_41.txt',
#  'lootcrate__logo_3.txt',
#  'amazon__27.txt',
#  'raid_shadow_legends__logo_7.txt',
#  'nordvpn__21.txt',
#  'dollar_shave_club__logo_29.txt',
#  'squarespace__33.txt',
#  'lootcrate__logo_17.txt',
#  'republic_of_gamers__30.txt',
#  'manscaped__logo_19.txt',
#  'gfuel__6.txt',
#  'brilliant_org__20.txt',
#  'logitech__logo_31.txt',
#  'war_thunder__logo_0.txt',
#  'microsoft__logo_32.txt',
#  'logitech__18.txt',
#  'coca_cola__21.txt',
#  'rhinoshield__logo_18.txt',
#  'surfshark__logo_22.txt',
#  'corsair__3.txt',
#  'brilliant_org__4.txt',
#  'war_thunder__43.txt',
#  'squarespace__13.txt',
#  'republic_of_gamers__logo_15.txt',
#  'uber_eats__40.txt',
#  'logitech__logo_13.txt',
#  'raid_shadow_legends__logo_11.txt',
#  'republic_of_gamers__46.txt',
#  'expressvpn__29.txt',
#  'republic_of_gamers__logo_7.txt',
#  'redbull__27.txt',
#  'redbull__logo_37.txt',
#  'gorillas__logo_21.txt',
#  'redbull__47.txt',
#  'worlds_of_warships__47.txt',
#  'levlup__logo_5.txt',
#  'gfuel__22.txt',
#  'redbull__logo_17.txt',
#  'tunnelbear_vpn__51.txt',
#  'nordvpn__logo_30.txt',
#  'coca_cola__logo_5.txt',
#  'displate__logo_34.txt',
#  'gfuel__13.txt',
#  'expressvpn__0.txt',
#  'expressvpn__logo_1.txt',
#  'corsair__logo_41.txt',
#  'uber_eats__logo_0.txt',
#  'gfuel__35.txt',
#  'fruitz__7.txt',
#  'fruitz__logo_1.txt',
#  'kiwico__logo_46.txt',
#  'tunnelbear_vpn__23.txt',
#  'kiwico__logo_22.txt',
#  'squarespace__logo_20.txt',
#  'lootcrate__1.txt',
#  'nordvpn__logo_28.txt',
#  'skillshare__logo_15.txt',
#  'hello_fresh__logo_7.txt',
#  'world_of_tanks__logo_28.txt',
#  'nordvpn__logo_10.txt',
#  'audible__17.txt',
#  'coca_cola__39.txt',
#  'microsoft__logo_27.txt',
#  'uber_eats__logo_25.txt',
#  'skillshare__43.txt',
#  'crunchyroll__logo_34.txt',
#  'honey__logo_41.txt',
#  'skillshare__logo_26.txt',
#  'nordvpn__logo_31.txt',
#  'worlds_of_warships__50.txt',
#  'expressvpn__21.txt',
#  'skillshare__logo_19.txt',
#  'microsoft__7.txt',
#  'coca_cola__28.txt',
#  'audible__logo_28.txt',
#  'war_thunder__logo_31.txt',
#  'world_of_tanks__logo_2.txt',
#  'skillshare__37.txt',
#  'hello_fresh__27.txt',
#  'dollar_shave_club__3.txt',
#  'state_of_survival__9.txt',
#  'lootcrate__logo_23.txt',
#  'worlds_of_warships__26.txt',
#  'gfuel__logo_38.txt',
#  'redbull__logo_38.txt',
#  'audible__28.txt',
#  'hello_fresh__25.txt',
#  'expressvpn__logo_17.txt',
#  'honey__logo_0.txt',
#  'tunnelbear_vpn__45.txt',
#  'hello_fresh__logo_28.txt',
#  'expressvpn__logo_13.txt',
#  'squarespace__36.txt',
#  'nordvpn__logo_11.txt',
#  'war_thunder__logo_46.txt',
#  'skillshare__18.txt',
#  'brilliant_org__2.txt',
#  'logitech__24.txt',
#  'nordvpn__logo_22.txt',
#  'republic_of_gamers__logo_5.txt',
#  'gfuel__16.txt',
#  'republic_of_gamers__17.txt',
#  'logitech__logo_14.txt',
#  'microsoft__logo_15.txt',
#  'ridge_wallet__12.txt',
#  'rhinoshield__logo_3.txt',
#  'squarespace__logo_0.txt',
#  'war_thunder__2.txt',
#  'skillshare__27.txt',
#  'republic_of_gamers__6.txt',
#  'amazon__6.txt',
#  'world_of_tanks__28.txt',
#  'uber_eats__logo_30.txt',
#  'audible__10.txt',
#  'gorillas__10.txt',
#  'brilliant_org__logo_4.txt',
#  'uber_eats__32.txt',
#  'expressvpn__logo_2.txt',
#  'lootcrate__20.txt',
#  'amazon__logo_12.txt',
#  'redbull__46.txt',
#  'kiwico__logo_21.txt',
#  'coca_cola__36.txt',
#  'kiwico__logo_1.txt',
#  'worlds_of_warships__logo_34.txt',
#  'kiwico__logo_30.txt',
#  'kiwico__logo_25.txt',
#  'nordvpn__1.txt',
#  'surfshark__19.txt',
#  'tunnelbear_vpn__40.txt',
#  'uber_eats__logo_10.txt',
#  'surfshark__logo_9.txt',
#  'republic_of_gamers__28.txt',
#  'skillshare__logo_4.txt',
#  'dollar_shave_club__logo_42.txt',
#  'brilliant_org__11.txt',
#  'surfshark__40.txt',
#  'worlds_of_warships__44.txt',
#  'nordvpn__27.txt',
#  'state_of_survival__logo_9.txt',
#  'lootcrate__23.txt',
#  'genshin_impact__30.txt',
#  'republic_of_gamers__29.txt',
#  'kiwico__31.txt',
#  'ridge_wallet__29.txt',
#  'ridge_wallet__40.txt',
#  'manscaped__logo_21.txt',
#  'honey__22.txt',
#  'gfuel__19.txt',
#  'squarespace__15.txt',
#  'rhinoshield__logo_20.txt',
#  'displate__logo_24.txt',
#  'squarespace__logo_40.txt',
#  'world_of_tanks__31.txt',
#  'worlds_of_warships__56.txt',
#  'tunnelbear_vpn__32.txt',
#  'microsoft__41.txt',
#  'corsair__logo_16.txt',
#  'ridge_wallet__23.txt',
#  'kiwico__logo_9.txt',
#  'lootcrate__logo_20.txt',
#  'expressvpn__20.txt',
#  'nordvpn__logo_6.txt',
#  'logitech__logo_11.txt',
#  'corsair__logo_17.txt',
#  'uber_eats__logo_21.txt',
#  'tunnelbear_vpn__38.txt',
#  'crunchyroll__logo_25.txt',
#  'kiwico__logo_40.txt',
#  'kiwico__logo_10.txt',
#  'genshin_impact__16.txt',
#  'world_of_tanks__32.txt',
#  'logitech__logo_9.txt',
#  'logitech__logo_15.txt',
#  'amazon__11.txt',
#  'nordvpn__3.txt',
#  'logitech__38.txt',
#  'state_of_survival__logo_26.txt',
#  'worlds_of_warships__46.txt',
#  'nordvpn__33.txt',
#  'expressvpn__logo_35.txt',
#  'uber_eats__42.txt',
#  'amazon__33.txt',
#  'amazon__12.txt',
#  'world_of_tanks__52.txt',
#  'ridge_wallet__15.txt',
#  'coca_cola__16.txt',
#  'corsair__logo_10.txt',
#  'corsair__logo_4.txt',
#  'brilliant_org__24.txt',
#  'uber_eats__logo_16.txt',
#  'republic_of_gamers__21.txt',
#  'war_thunder__13.txt',
#  'fruitz__39.txt',
#  'manscaped__47.txt',
#  'corsair__53.txt',
#  'winamax__logo_0.txt',
#  'squarespace__logo_9.txt',
#  'rhinoshield__logo_19.txt',
#  'world_of_tanks__logo_40.txt',
#  'war_thunder__logo_15.txt',
#  'world_of_tanks__48.txt',
#  'fruitz__0.txt',
#  'nordvpn__logo_13.txt',
#  'amazon__logo_0.txt',
#  'manscaped__logo_9.txt',
#  'redbull__31.txt',
#  'surfshark__logo_2.txt',
#  'coca_cola__2.txt',
#  'gfuel__logo_14.txt',
#  'hello_fresh__logo_2.txt',
#  'amazon__29.txt',
#  'dollar_shave_club__18.txt',
#  'nordvpn__10.txt',
#  'hello_fresh__42.txt',
#  'lootcrate__25.txt',
#  'manscaped__logo_3.txt',
#  'brilliant_org__logo_14.txt',
#  'skillshare__logo_12.txt',
#  'republic_of_gamers__logo_23.txt',
#  'nordvpn__logo_35.txt',
#  'squarespace__31.txt',
#  'honey__5.txt',
#  'amazon__logo_39.txt',
#  'raid_shadow_legends__logo_21.txt',
#  'amazon__logo_19.txt',
#  'republic_of_gamers__logo_19.txt',
#  'uber_eats__15.txt',
#  'brilliant_org__14.txt',
#  'audible__7.txt',
#  'state_of_survival__41.txt',
#  'expressvpn__logo_32.txt',
#  'lootcrate__logo_7.txt',
#  'republic_of_gamers__15.txt',
#  'manscaped__46.txt',
#  'state_of_survival__logo_11.txt',
#  'crunchyroll__44.txt',
#  'war_thunder__logo_38.txt',
#  'levlup__23.txt',
#  'dollar_shave_club__logo_43.txt',
#  'amazon__57.txt',
#  'coca_cola__logo_10.txt',
#  'nordvpn__logo_26.txt',
#  'redbull__21.txt',
#  'logitech__15.txt',
#  'corsair__logo_34.txt',
#  'corsair__logo_32.txt',
#  'world_of_tanks__logo_44.txt',
#  'rhinoshield__logo_25.txt',
#  'microsoft__logo_7.txt',
#  'crunchyroll__45.txt',
#  'gfuel__logo_0.txt',
#  'world_of_tanks__39.txt',
#  'republic_of_gamers__41.txt',
#  'dbrand__logo_30.txt',
#  'ridge_wallet__37.txt',
#  'hello_fresh__21.txt',
#  'crunchyroll__14.txt',
#  'levlup__logo_19.txt',
#  'gfuel__49.txt',
#  'ridge_wallet__4.txt',
#  'world_of_tanks__34.txt',
#  'state_of_survival__logo_25.txt',
#  'squarespace__20.txt',
#  'raid_shadow_legends__logo_31.txt',
#  'skillshare__logo_20.txt',
#  'uber_eats__logo_26.txt',
#  'corsair__logo_44.txt',
#  'corsair__logo_31.txt',
#  'levlup__16.txt',
#  'world_of_tanks__logo_45.txt',
#  'winamax__logo_4.txt',
#  'amazon__19.txt',
#  'world_of_tanks__49.txt',
#  'coca_cola__58.txt',
#  'coca_cola__7.txt',
#  'dollar_shave_club__20.txt',
#  'amazon__logo_11.txt',
#  'state_of_survival__logo_0.txt',
#  'winamax__logo_17.txt',
#  'amazon__logo_34.txt',
#  'displate__logo_31.txt',
#  'crunchyroll__logo_10.txt',
#  'amazon__30.txt',
#  'hello_fresh__40.txt',
#  'winamax__23.txt',
#  'amazon__55.txt',
#  'logitech__9.txt',
#  'corsair__6.txt',
#  'coca_cola__logo_26.txt',
#  'redbull__13.txt',
#  'dollar_shave_club__logo_33.txt',
#  'coca_cola__logo_8.txt',
#  'logitech__40.txt',
#  'nordvpn__logo_36.txt',
#  'amazon__54.txt',
#  'coca_cola__22.txt',
#  'logitech__logo_25.txt',
#  'displate__logo_25.txt',
#  'squarespace__46.txt',
#  'skillshare__logo_8.txt',
#  'worlds_of_warships__11.txt',
#  'audible__13.txt',
#  'gorillas__logo_30.txt',
#  'dollar_shave_club__logo_21.txt',
#  'manscaped__6.txt',
#  'gfuel__logo_22.txt',
#  'manscaped__8.txt',
#  'state_of_survival__logo_35.txt',
#  'microsoft__logo_33.txt',
#  'expressvpn__logo_5.txt',
#  'worlds_of_warships__16.txt',
#  'uber_eats__1.txt',
#  'amazon__logo_36.txt',
#  'winamax__logo_11.txt',
#  'world_of_tanks__9.txt',
#  'levlup__logo_2.txt',
#  'nordvpn__32.txt',
#  'surfshark__logo_21.txt',
#  'winamax__logo_39.txt',
#  'lootcrate__logo_22.txt',
#  'skillshare__38.txt',
#  'expressvpn__logo_6.txt',
#  'levlup__24.txt',
#  'levlup__7.txt',
#  'rhinoshield__21.txt',
#  'uber_eats__logo_43.txt',
#  'levlup__logo_33.txt',
#  'hello_fresh__logo_5.txt',
#  'republic_of_gamers__logo_13.txt',
#  'lootcrate__logo_42.txt',
#  'lootcrate__37.txt',
#  'amazon__50.txt',
#  'honey__32.txt',
#  'dollar_shave_club__48.txt',
#  'crunchyroll__logo_3.txt',
#  'uber_eats__logo_31.txt',
#  'tunnelbear_vpn__4.txt',
#  'lootcrate__logo_1.txt',
#  'republic_of_gamers__logo_45.txt',
#  'surfshark__logo_8.txt',
#  'ridge_wallet__35.txt',
#  'hello_fresh__logo_30.txt',
#  'kiwico__logo_2.txt',
#  'world_of_tanks__logo_21.txt',
#  'audible__logo_17.txt',
#  'war_thunder__22.txt',
#  'microsoft__logo_22.txt',
#  'hello_fresh__logo_24.txt',
#  'manscaped__7.txt',
#  'skillshare__logo_17.txt',
#  'war_thunder__logo_32.txt',
#  'logitech__12.txt',
#  'surfshark__15.txt',
#  'dollar_shave_club__logo_39.txt',
#  'displate__logo_44.txt',
#  'redbull__logo_16.txt',
#  'squarespace__logo_8.txt',
#  'coca_cola__4.txt',
#  'tunnelbear_vpn__logo_17.txt',
#  'world_of_tanks__44.txt',
#  'tunnelbear_vpn__55.txt',
#  'gfuel__25.txt',
#  'corsair__logo_39.txt',
#  'skillshare__11.txt',
#  'republic_of_gamers__9.txt',
#  'hello_fresh__logo_41.txt',
#  'surfshark__logo_15.txt',
#  'honey__6.txt',
#  'tunnelbear_vpn__10.txt',
#  'honey__30.txt',
#  'gfuel__18.txt',
#  'crunchyroll__logo_6.txt',
#  'state_of_survival__4.txt',
#  'manscaped__26.txt',
#  'crunchyroll__18.txt',
#  'republic_of_gamers__38.txt',
#  'microsoft__23.txt',
#  'levlup__42.txt',
#  'uber_eats__logo_12.txt',
#  'uber_eats__logo_36.txt',
#  'dollar_shave_club__logo_15.txt',
#  'world_of_tanks__logo_10.txt',
#  'republic_of_gamers__logo_11.txt',
#  'microsoft__17.txt',
#  'crunchyroll__logo_42.txt',
#  'dollar_shave_club__logo_27.txt',
#  'worlds_of_warships__13.txt',
#  'surfshark__20.txt',
#  'amazon__51.txt',
#  'gfuel__45.txt',
#  'nordvpn__13.txt',
#  'winamax__logo_32.txt',
#  'amazon__45.txt',
#  'worlds_of_warships__17.txt',
#  'genshin_impact__logo_1.txt',
#  'coca_cola__logo_15.txt',
#  'coca_cola__logo_13.txt',
#  'brilliant_org__31.txt',
#  'surfshark__logo_5.txt',
#  'skillshare__logo_16.txt',
#  'fruitz__21.txt',
#  'surfshark__16.txt',
#  'dollar_shave_club__34.txt',
#  'expressvpn__11.txt',
#  'surfshark__logo_1.txt',
#  'surfshark__logo_20.txt',
#  'microsoft__53.txt',
#  'squarespace__logo_32.txt',
#  'war_thunder__46.txt',
#  'expressvpn__3.txt',
#  'world_of_tanks__21.txt',
#  'corsair__logo_19.txt',
#  'world_of_tanks__logo_5.txt',
#  'lootcrate__logo_21.txt',
#  'winamax__11.txt',
#  'squarespace__logo_21.txt',
#  'crunchyroll__logo_11.txt',
#  'gfuel__44.txt',
#  'kiwico__logo_8.txt',
#  'redbull__40.txt',
#  'coca_cola__40.txt',
#  'honey__logo_34.txt',
#  'microsoft__13.txt',
#  'surfshark__17.txt',
#  'state_of_survival__24.txt',
#  'winamax__43.txt',
#  'logitech__35.txt',
#  'coca_cola__logo_34.txt',
#  'coca_cola__29.txt',
#  'dbrand__34.txt',
#  'redbull__logo_3.txt',
#  'war_thunder__9.txt',
#  'corsair__logo_24.txt',
#  'amazon__4.txt',
#  'republic_of_gamers__43.txt',
#  'raid_shadow_legends__logo_17.txt',
#  'logitech__logo_5.txt',
#  'crunchyroll__26.txt',
#  'redbull__26.txt',
#  'tunnelbear_vpn__31.txt',
#  'world_of_tanks__logo_1.txt',
#  'genshin_impact__logo_15.txt',
#  'dollar_shave_club__27.txt',
#  'expressvpn__logo_41.txt',
#  'brilliant_org__3.txt',
#  'displate__logo_46.txt',
#  'crunchyroll__logo_22.txt',
#  'audible__logo_15.txt',
#  'levlup__logo_41.txt',
#  'tunnelbear_vpn__logo_22.txt',
#  'levlup__3.txt',
#  'redbull__1.txt',
#  'lootcrate__logo_39.txt',
#  'rhinoshield__logo_37.txt',
#  'gfuel__10.txt',
#  'nordvpn__logo_18.txt',
#  'raid_shadow_legends__logo_2.txt',
#  'uber_eats__logo_33.txt',
#  'audible__15.txt',
#  'dollar_shave_club__0.txt',
#  'expressvpn__15.txt',
#  'world_of_tanks__logo_32.txt',
#  'coca_cola__logo_30.txt',
#  'skillshare__logo_21.txt',
#  'gfuel__32.txt',
#  'winamax__35.txt',
#  'world_of_tanks__14.txt',
#  'kiwico__logo_14.txt',
#  'logitech__10.txt',
#  'rhinoshield__logo_43.txt',
#  'tunnelbear_vpn__logo_14.txt',
#  'displate__logo_18.txt',
#  'fruitz__12.txt',
#  'surfshark__43.txt',
#  'coca_cola__55.txt',
#  'ridge_wallet__0.txt',
#  'redbull__logo_23.txt',
#  'amazon__logo_4.txt',
#  'logitech__5.txt',
#  'surfshark__logo_7.txt',
#  'expressvpn__logo_36.txt',
#  'amazon__logo_25.txt',
#  'hello_fresh__logo_42.txt',
#  'winamax__logo_24.txt',
#  'winamax__logo_1.txt',
#  'kiwico__logo_11.txt',
#  'corsair__logo_18.txt',
#  'redbull__2.txt',
#  'surfshark__14.txt',
#  'gfuel__43.txt',
#  'winamax__logo_35.txt',
#  'redbull__logo_6.txt',
#  'brilliant_org__40.txt',
#  'manscaped__logo_2.txt',
#  'worlds_of_warships__27.txt',
#  'worlds_of_warships__logo_35.txt',
#  'levlup__15.txt',
#  'fruitz__8.txt',
#  'expressvpn__logo_27.txt',
#  'logitech__25.txt',
#  'world_of_tanks__logo_39.txt',
#  'worlds_of_warships__30.txt',
#  'uber_eats__logo_3.txt',
#  'gfuel__33.txt',
#  'hello_fresh__35.txt',
#  'worlds_of_warships__24.txt',
#  'redbull__28.txt',
#  'coca_cola__20.txt',
#  'corsair__25.txt',
#  'state_of_survival__logo_41.txt',
#  'gorillas__27.txt',
#  'gfuel__logo_26.txt',
#  'tunnelbear_vpn__logo_10.txt',
#  'uber_eats__logo_20.txt',
#  'hello_fresh__6.txt',
#  'brilliant_org__30.txt',
#  'tunnelbear_vpn__0.txt',
#  'nordvpn__logo_39.txt',
#  'state_of_survival__logo_1.txt',
#  'world_of_tanks__47.txt',
#  'fruitz__32.txt',
#  'audible__5.txt',
#  'gfuel__15.txt',
#  'surfshark__logo_0.txt',
#  'crunchyroll__logo_33.txt',
#  'coca_cola__35.txt',
#  'surfshark__5.txt',
#  'winamax__48.txt',
#  'honey__18.txt',
#  'kiwico__logo_17.txt',
#  'fruitz__logo_20.txt',
#  'uber_eats__47.txt',
#  'fruitz__27.txt',
#  'corsair__13.txt',
#  'kiwico__logo_36.txt',
#  'amazon__9.txt',
#  'redbull__logo_22.txt',
#  'levlup__37.txt',
#  'microsoft__logo_10.txt',
#  'republic_of_gamers__11.txt',
#  'microsoft__24.txt',
#  'redbull__logo_36.txt',
#  'redbull__37.txt',
#  'worlds_of_warships__7.txt',
#  'coca_cola__44.txt',
#  'skillshare__logo_7.txt',
#  'genshin_impact__34.txt',
#  'skillshare__logo_37.txt',
#  'war_thunder__logo_6.txt',
#  'logitech__0.txt',
#  'tunnelbear_vpn__logo_11.txt',
#  'raid_shadow_legends__38.txt',
#  'skillshare__logo_9.txt',
#  'brilliant_org__13.txt',
#  'war_thunder__16.txt',
#  'dollar_shave_club__24.txt',
#  'worlds_of_warships__25.txt',
#  'surfshark__50.txt',
#  'tunnelbear_vpn__logo_33.txt',
#  'world_of_tanks__43.txt',
#  'worlds_of_warships__logo_28.txt',
#  'worlds_of_warships__54.txt',
#  'gfuel__logo_20.txt',
#  'world_of_tanks__logo_19.txt',
#  'microsoft__42.txt',
#  'levlup__logo_46.txt',
#  'levlup__6.txt',
#  'logitech__logo_16.txt',
#  'hello_fresh__logo_38.txt',
#  'tunnelbear_vpn__35.txt',
#  'displate__logo_39.txt',
#  'rhinoshield__logo_44.txt',
#  'displate__15.txt',
#  'gfuel__23.txt',
#  'manscaped__logo_42.txt',
#  'brilliant_org__logo_23.txt',
#  'crunchyroll__13.txt',
#  'worlds_of_warships__logo_22.txt',
#  'expressvpn__logo_40.txt',
#  'coca_cola__logo_16.txt',
#  'state_of_survival__34.txt',
#  'republic_of_gamers__39.txt',
#  'world_of_tanks__logo_15.txt',
#  'amazon__logo_13.txt',
#  'nordvpn__23.txt',
#  'redbull__18.txt',
#  'logitech__logo_24.txt',
#  'war_thunder__17.txt',
#  'amazon__22.txt',
#  'brilliant_org__logo_29.txt',
#  'crunchyroll__28.txt',
#  'nordvpn__logo_3.txt',
#  'expressvpn__31.txt',
#  'manscaped__logo_0.txt',
#  'redbull__logo_12.txt',
#  'microsoft__logo_12.txt',
#  'raid_shadow_legends__logo_24.txt',
#  'amazon__42.txt',
#  'logitech__logo_45.txt',
#  'uber_eats__logo_34.txt',
#  'skillshare__logo_34.txt',
#  'worlds_of_warships__49.txt',
#  'gfuel__logo_23.txt',
#  'gfuel__46.txt',
#  'redbull__15.txt',
#  'manscaped__19.txt',
#  'expressvpn__2.txt',
#  'worlds_of_warships__65.txt',
#  'winamax__19.txt',
#  'manscaped__27.txt',
#  'tunnelbear_vpn__52.txt',
#  'levlup__36.txt',
#  'logitech__logo_35.txt',
#  'kiwico__logo_44.txt',
#  'war_thunder__logo_7.txt',
#  'nordvpn__38.txt',
#  'republic_of_gamers__logo_12.txt',
#  'uber_eats__14.txt',
#  'microsoft__44.txt',
#  'gorillas__logo_7.txt',
#  'coca_cola__0.txt',
#  'levlup__33.txt',
#  'fruitz__logo_41.txt',
#  'redbull__12.txt',
#  'squarespace__25.txt',
#  'winamax__41.txt',
#  'expressvpn__logo_30.txt',
#  'kiwico__logo_29.txt',
#  'coca_cola__logo_22.txt',
#  'logitech__19.txt',
#  'amazon__46.txt',
#  'microsoft__logo_14.txt',
#  'squarespace__logo_37.txt',
#  'winamax__27.txt',
#  'crunchyroll__24.txt',
#  'uber_eats__7.txt',
#  'logitech__1.txt',
#  'state_of_survival__38.txt',
#  'rhinoshield__logo_0.txt',
#  'microsoft__logo_21.txt',
#  'world_of_tanks__6.txt',
#  'dollar_shave_club__logo_13.txt',
#  'levlup__35.txt',
#  'redbull__19.txt',
#  'gfuel__logo_31.txt',
#  'redbull__logo_41.txt',
#  'redbull__logo_8.txt',
#  'fruitz__41.txt',
#  'redbull__logo_33.txt',
#  'fruitz__logo_17.txt',
#  'fruitz__31.txt',
#  'war_thunder__logo_19.txt',
#  'lootcrate__3.txt',
#  'gorillas__30.txt',
#  'manscaped__21.txt',
#  'squarespace__8.txt',
#  'rhinoshield__logo_11.txt',
#  'state_of_survival__31.txt',
#  'lootcrate__logo_32.txt',
#  'redbull__32.txt',
#  'lootcrate__41.txt',
#  'war_thunder__12.txt',
#  'nordvpn__logo_9.txt',
#  'crunchyroll__logo_17.txt',
#  'levlup__31.txt',
#  'winamax__5.txt',
#  'war_thunder__7.txt',
#  'redbull__logo_14.txt',
#  'crunchyroll__logo_21.txt',
#  'logitech__logo_30.txt',
#  'ridge_wallet__18.txt',
#  'war_thunder__11.txt',
#  'worlds_of_warships__18.txt',
#  'worlds_of_warships__61.txt',
#  'kiwico__logo_38.txt',
#  'redbull__45.txt',
#  'corsair__41.txt',
#  'nordvpn__35.txt',
#  'nordvpn__42.txt',
#  'worlds_of_warships__logo_37.txt',
#  'lootcrate__9.txt',
#  'state_of_survival__25.txt',
#  'dollar_shave_club__28.txt',
#  'worlds_of_warships__39.txt',
#  'kiwico__logo_37.txt',
#  'kiwico__logo_13.txt',
#  'logitech__4.txt',
#  'crunchyroll__8.txt',
#  'gfuel__28.txt',
#  'state_of_survival__35.txt',
#  'gfuel__logo_6.txt',
#  'amazon__logo_10.txt',
#  'winamax__logo_5.txt',
#  'gfuel__logo_25.txt',
#  'tunnelbear_vpn__37.txt',
#  'state_of_survival__33.txt',
#  'republic_of_gamers__logo_42.txt',
#  'redbull__44.txt',
#  'manscaped__logo_28.txt',
#  'redbull__logo_27.txt',
#  'gfuel__logo_32.txt',
#  'levlup__logo_7.txt',
#  'war_thunder__34.txt',
#  'republic_of_gamers__logo_14.txt',
#  'brilliant_org__logo_11.txt',
#  'world_of_tanks__logo_6.txt',
#  'world_of_tanks__20.txt',
#  'amazon__23.txt',
#  'redbull__35.txt',
#  'redbull__logo_42.txt',
#  'nordvpn__logo_15.txt',
#  'amazon__20.txt',
#  'world_of_tanks__logo_29.txt',
#  'nordvpn__7.txt',
#  'skillshare__logo_6.txt',
#  'logitech__logo_4.txt',
#  'corsair__21.txt',
#  'logitech__28.txt',
#  'genshin_impact__7.txt',
#  'gorillas__8.txt',
#  ...]

# %%
for image in os.listdir(img_dir):

  if image in ['train','test']:
    continue

  if image in test_images or image in train_images:
    image_root = image
  else:
    image_root = image[:image.rfind('_')]+ '.png'

  if image_root in test_images:
    shutil.move(img_dir + image, img_dir + 'test/' + image)
  if image_root in train_images:
    shutil.move(img_dir + image, img_dir + 'train/' + image)

# %%
for txt in os.listdir(txt_dir):
  if txt in ['train','test']:
    continue

  if txt in test_txt or txt in train_txt:
    txt_root = txt
  else:
    txt_root = txt[:txt.rfind('_')]+ '.txt'


  if txt_root in test_txt:
    shutil.move(txt_dir + txt, txt_dir + 'test/' + txt)
  if txt_root in train_txt:
    shutil.move(txt_dir + txt, txt_dir + 'train/' + txt)
